# %% [markdown]
# <a href="https://colab.research.google.com/github/SimbakNetmind/series-de-tiempo/blob/01-Metodos-de-suavizado/00_Practica_Presentaci%C3%B3n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## ***Métodos de suavizado (SMA,WMA y EMA) Practica Presentación***

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# ## 🎯***Practica codigo (SMA,WMA,EMA)***

# %%
import numpy as np
import pandas as pd


# Serie de tiempo
data = [10, 12, 13, 16, 15, 20, 22, 21, 23, 25,
        26, 28, 30, 29, 31, 33, 35, 36, 38, 42]

serie = pd.Series(data)

#1. Media Móvil Simple (SMA)
k = 3
sma = serie.rolling(window=k).mean()


#2. Media Móvil Ponderada (WMA)
weights = np.array([0.2, 0.3, 0.5])

def wma(values):
    return np.dot(values, weights)

wma_series = serie.rolling(window=3).apply(wma, raw=True)


#3. Media Móvil Exponencial (EMA)
alpha = 0.3
ema = serie.ewm(alpha=alpha, adjust=False).mean()

#Resultados
df = pd.DataFrame({
    "y": serie,
    "SMA": sma,
    "WMA": wma_series,
    "EMA": ema
})

print(df)
# Out:
#      y        SMA   WMA        EMA
# 0   10        NaN   NaN  10.000000
# 1   12        NaN   NaN  10.600000
# 2   13  11.666667  12.1  11.320000
# 3   16  13.666667  14.3  12.724000
# 4   15  14.666667  14.9  13.406800
# 5   20  17.000000  17.7  15.384760
# 6   22  19.000000  20.0  17.369332
# 7   21  21.000000  21.1  18.458532
# 8   23  22.000000  22.2  19.820973
# 9   25  23.000000  23.6  21.374681
# 10  26  24.666667  25.1  22.762277
# 11  28  26.333333  26.8  24.333594
# 12  30  28.000000  28.6  26.033516
# 13  29  29.000000  29.1  26.923461
# 14  31  30.000000  30.2  28.146423
# 15  33  31.000000  31.6  29.602496
# 16  35  33.000000  33.6  31.221747
# 17  36  34.666667  35.1  32.655223
# 18  38  36.333333  36.8  34.258656
# 19  42  38.666667  39.6  36.581059

# %% [markdown]
# ## ***📈 Grafica serie (SMA,WMA,EMA) vs Dato Reales***

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))
sns.lineplot(data=df[['y', 'SMA', 'WMA', 'EMA']])
plt.title('Comparison of Smoothing Methods')
plt.xlabel('Time Point')
plt.ylabel('Value')
plt.legend(['Original Series (y)', 'SMA', 'WMA', 'EMA'])
plt.grid(True)
plt.show()
